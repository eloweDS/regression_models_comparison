# %%
import pandas as pd
import numpy as np

file_path = 'taxi_trip.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0          748.0               2.75                1.0   75.00   24
# 1         1187.0               3.43                1.0  105.00   24
# 2          730.0               3.12                1.0   71.25    0
# 3          671.0               5.63                3.0   90.00    0
# 4          329.0               2.09                1.0   45.00   12
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 1              13.200     142.200              0
# 2              26.625      97.875              1
# 3               9.750      99.750              0
# 4              13.200      70.200              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209673 entries, 0 to 209672
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_duration       209673 non-null  float64
#  1   distance_traveled   209673 non-null  float64
#  2   num_of_passengers   209673 non-null  float64
#  3   fare                209673 non-null  float64
#  4   tip                 209673 non-null  int64
#  5   miscellaneous_fees  209673 non-null  float64
#  6   total_fare          209673 non-null  float64
#  7   surge_applied       209673 non-null  int64
# dtypes: float64(6), int64(2)
# memory usage: 12.8 MB

# %%
df.describe()
# Out:
#        trip_duration  distance_traveled  num_of_passengers           fare  \
# count  209673.000000      209673.000000      209673.000000  209673.000000
# mean     1173.181478           5.054431           1.292808      99.623431
# std      4775.653621         125.217419           0.930754      85.602702
# min         0.000000           0.020000           0.000000       0.000000
# 25%       446.000000           1.950000           1.000000      52.500000
# 50%       707.000000           3.200000           1.000000      75.000000
# 75%      1098.000000           5.730000           1.000000     116.250000
# max     86387.000000       57283.910000           9.000000    4466.250000
#
#                  tip  miscellaneous_fees     total_fare  surge_applied
# count  209673.000000       209673.000000  209673.000000  209673.000000
# mean       13.030824           15.136829     127.791084       0.280523
# std        20.367764           12.553436      98.797374       0.449256
# min         0.000000           -0.500000       0.000000       0.000000
# 25%         0.000000            6.000000      70.200000       0.000000
# 50%         9.000000            9.750000     101.700000       0.000000
# 75%        20.000000           26.450000     152.250000       1.000000
# max      2500.000000          435.000000    4472.250000       1.000000

# %%
null_values = df.isnull().sum()
null_values
# Out:
# trip_duration         0
# distance_traveled     0
# num_of_passengers     0
# fare                  0
# tip                   0
# miscellaneous_fees    0
# total_fare            0
# surge_applied         0
# dtype: int64

# %%
distance_outlier = df[df['distance_traveled']>6000]
distance_outlier
# Out:
#         trip_duration  distance_traveled  num_of_passengers     fare  tip  \
# 197339         1734.0           57283.91                1.0  187.125   20
#
#         miscellaneous_fees  total_fare  surge_applied
# 197339              50.875       258.0              0

# %%
df = df[df['distance_traveled']<=6000]
df
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied
# 0                    6.300     105.300              0
# 1                   13.200     142.200              0
# 2                   26.625      97.875              1
# 3                    9.750      99.750              0
# 4                   13.200      70.200              0
# ...                    ...         ...            ...
# 209668               5.800     202.800              0
# 209669              34.575      95.325              1
# 209670               6.000      69.750              0
# 209671              13.500      69.750              0
# 209672               2.250     339.750              0
#
# [209672 rows x 8 columns]

# %%
df = df[df['trip_duration']>=60]
df
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied
# 0                    6.300     105.300              0
# 1                   13.200     142.200              0
# 2                   26.625      97.875              1
# 3                    9.750      99.750              0
# 4                   13.200      70.200              0
# ...                    ...         ...            ...
# 209668               5.800     202.800              0
# 209669              34.575      95.325              1
# 209670               6.000      69.750              0
# 209671              13.500      69.750              0
# 209672               2.250     339.750              0
#
# [207020 rows x 8 columns]

# %%
df = df[df['fare']>0]
df
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied
# 0                    6.300     105.300              0
# 1                   13.200     142.200              0
# 2                   26.625      97.875              1
# 3                    9.750      99.750              0
# 4                   13.200      70.200              0
# ...                    ...         ...            ...
# 209668               5.800     202.800              0
# 209669              34.575      95.325              1
# 209670               6.000      69.750              0
# 209671              13.500      69.750              0
# 209672               2.250     339.750              0
#
# [206897 rows x 8 columns]

# %%
df = df[df['num_of_passengers']>0]
df
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied
# 0                    6.300     105.300              0
# 1                   13.200     142.200              0
# 2                   26.625      97.875              1
# 3                    9.750      99.750              0
# 4                   13.200      70.200              0
# ...                    ...         ...            ...
# 209668               5.800     202.800              0
# 209669              34.575      95.325              1
# 209670               6.000      69.750              0
# 209671              13.500      69.750              0
# 209672               2.250     339.750              0
#
# [206184 rows x 8 columns]

# %%
df = df[df['distance_traveled']>0]
df
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied
# 0                    6.300     105.300              0
# 1                   13.200     142.200              0
# 2                   26.625      97.875              1
# 3                    9.750      99.750              0
# 4                   13.200      70.200              0
# ...                    ...         ...            ...
# 209668               5.800     202.800              0
# 209669              34.575      95.325              1
# 209670               6.000      69.750              0
# 209671              13.500      69.750              0
# 209672               2.250     339.750              0
#
# [206184 rows x 8 columns]

# %%
import time
import cProfile
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame with features and target variable
# Example: Replace this with your dataset loading step
# df = pd.read_csv('your_dataset.csv')

X = df.drop(columns=['total_fare'])
y = df['total_fare']

# Normalize features using StandardScaler
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# Dictionary to store performance metrics for each model
results = {
    'Regression Tree': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []},
    'Ridge Regression': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []},
    'Lasso Regression': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []},
    'Principal Component Regression (PCR)': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []},
    'Regression Splines': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []},
    'Support Vector Regression (SVR)': {'MSE': [], 'RMSE': [], 'RSE': [], 'RSS': [], 'R^2': []}
}

num_features = X.shape[1]

def run_models():
    """Function to run models and calculate performance metrics."""
    for _ in range(20):  # Number of iterations
        # Time entire iteration
        start_iteration = time.time()

        X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.3, random_state=None)

        # Defining models
        models = {
            'Regression Tree': DecisionTreeRegressor(),
            'Ridge Regression': Ridge(),
            'Lasso Regression': Lasso(),
            'Principal Component Regression (PCR)': make_pipeline(PCA(n_components=num_features), LinearRegression()),
            'Regression Splines': make_pipeline(PolynomialFeatures(degree=3), LinearRegression()),
            'Support Vector Regression (SVR)': SVR(kernel='linear')
        }

        # Fitting models and computing metrics
        for model_name, model in models.items():
            start_model = time.time()
            
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            mse = mean_squared_error(y_test, y_pred)
            rmse = np.sqrt(mse)
            rss = np.sum((y_test - y_pred) ** 2)
            rse = np.sqrt(rss / (len(y_test) - X_test.shape[1] - 1))
            r2 = r2_score(y_test, y_pred)
            
            results[model_name]['MSE'].append(mse)
            results[model_name]['RMSE'].append(rmse)
            results[model_name]['RSE'].append(rse)
            results[model_name]['RSS'].append(rss)
            results[model_name]['R^2'].append(r2)
            
            end_model = time.time()
            print(f"{model_name} Execution Time: {end_model - start_model:.2f} seconds")
        
        end_iteration = time.time()
        print(f"Iteration Execution Time: {end_iteration - start_iteration:.2f} seconds")

# Profile the run_models function
cProfile.run("run_models()")

# Calculate average results
average_results = {model: {metric: np.mean(scores) for metric, scores in metrics.items()} for model, metrics in results.items()}

# Convert results to a DataFrame for better visualization
results_df = pd.DataFrame(average_results).T
print(results_df)
# Out:
# Regression Tree Execution Time: 1.18 seconds
# Ridge Regression Execution Time: 0.18 seconds
# Lasso Regression Execution Time: 0.05 seconds
# Principal Component Regression (PCR) Execution Time: 0.31 seconds
# Regression Splines Execution Time: 2.06 seconds
# Support Vector Regression (SVR) Execution Time: 10.52 seconds
# Iteration Execution Time: 14.37 seconds
# Regression Tree Execution Time: 0.68 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.12 seconds
# Regression Splines Execution Time: 1.87 seconds
# Support Vector Regression (SVR) Execution Time: 15.32 seconds
# Iteration Execution Time: 18.07 seconds
# Regression Tree Execution Time: 0.62 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.52 seconds
# Support Vector Regression (SVR) Execution Time: 29.12 seconds
# Iteration Execution Time: 31.43 seconds
# Regression Tree Execution Time: 0.59 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.59 seconds
# Support Vector Regression (SVR) Execution Time: 14.42 seconds
# Iteration Execution Time: 16.78 seconds
# Regression Tree Execution Time: 0.60 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.43 seconds
# Support Vector Regression (SVR) Execution Time: 5.32 seconds
# Iteration Execution Time: 7.54 seconds
# Regression Tree Execution Time: 0.64 seconds
# Ridge Regression Execution Time: 0.03 seconds
# Lasso Regression Execution Time: 0.04 seconds
# Principal Component Regression (PCR) Execution Time: 0.10 seconds
# Regression Splines Execution Time: 1.44 seconds
# Support Vector Regression (SVR) Execution Time: 29.42 seconds
# Iteration Execution Time: 31.70 seconds
# Regression Tree Execution Time: 0.64 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.04 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.29 seconds
# Support Vector Regression (SVR) Execution Time: 11.97 seconds
# Iteration Execution Time: 14.07 seconds
# Regression Tree Execution Time: 0.50 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.02 seconds
# Principal Component Regression (PCR) Execution Time: 0.06 seconds
# Regression Splines Execution Time: 1.37 seconds
# Support Vector Regression (SVR) Execution Time: 17.23 seconds
# Iteration Execution Time: 19.23 seconds
# Regression Tree Execution Time: 0.57 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.54 seconds
# Support Vector Regression (SVR) Execution Time: 24.42 seconds
# Iteration Execution Time: 26.72 seconds
# Regression Tree Execution Time: 0.54 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.49 seconds
# Support Vector Regression (SVR) Execution Time: 40.39 seconds
# Iteration Execution Time: 42.58 seconds
# Regression Tree Execution Time: 0.50 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.28 seconds
# Support Vector Regression (SVR) Execution Time: 6.38 seconds
# Iteration Execution Time: 8.32 seconds
# Regression Tree Execution Time: 0.54 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.49 seconds
# Support Vector Regression (SVR) Execution Time: 22.24 seconds
# Iteration Execution Time: 24.43 seconds
# Regression Tree Execution Time: 0.52 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.02 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.39 seconds
# Support Vector Regression (SVR) Execution Time: 16.95 seconds
# Iteration Execution Time: 19.01 seconds
# Regression Tree Execution Time: 0.49 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.35 seconds
# Support Vector Regression (SVR) Execution Time: 12.35 seconds
# Iteration Execution Time: 14.34 seconds
# Regression Tree Execution Time: 0.53 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.43 seconds
# Support Vector Regression (SVR) Execution Time: 44.30 seconds
# Iteration Execution Time: 46.42 seconds
# Regression Tree Execution Time: 0.50 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.41 seconds
# Support Vector Regression (SVR) Execution Time: 40.29 seconds
# Iteration Execution Time: 42.37 seconds
# Regression Tree Execution Time: 0.49 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.37 seconds
# Support Vector Regression (SVR) Execution Time: 13.12 seconds
# Iteration Execution Time: 15.15 seconds
# Regression Tree Execution Time: 0.52 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.09 seconds
# Regression Splines Execution Time: 1.35 seconds
# Support Vector Regression (SVR) Execution Time: 25.61 seconds
# Iteration Execution Time: 27.63 seconds
# Regression Tree Execution Time: 0.58 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.10 seconds
# Regression Splines Execution Time: 1.43 seconds
# Support Vector Regression (SVR) Execution Time: 7.69 seconds
# Iteration Execution Time: 9.88 seconds
# Regression Tree Execution Time: 0.52 seconds
# Ridge Regression Execution Time: 0.02 seconds
# Lasso Regression Execution Time: 0.03 seconds
# Principal Component Regression (PCR) Execution Time: 0.08 seconds
# Regression Splines Execution Time: 1.50 seconds
# Support Vector Regression (SVR) Execution Time: 16.02 seconds
# Iteration Execution Time: 18.21 seconds
#          334381 function calls (332307 primitive calls) in 448.262 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.503    0.503  448.261  448.261 875223368.py:37(run_models)
#      5980    0.003    0.000    0.016    0.000 <frozen abc>:117(__instancecheck__)
# 3176/3169    0.002    0.000    0.005    0.000 <frozen abc>:121(__subclasscheck__)
#       720    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#       360    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:405(parent)
#         1    0.001    0.001  448.262  448.262 <string>:1(<module>)
#        40    0.450    0.011    0.450    0.011 __init__.py:179(_array_indexing)
#        40    0.002    0.000    0.119    0.003 __init__.py:188(_pandas_indexing)
#        80    0.001    0.000    0.001    0.000 __init__.py:215(_determine_key_type)
#        80    0.001    0.000    0.572    0.007 __init__.py:285(_safe_indexing)
#       440    0.001    0.000    0.001    0.000 __init__.py:33(using_copy_on_write)
#       160    0.000    0.000    0.000    0.000 __init__.py:953(_print_elapsed_time)
#      1180    0.009    0.000    1.334    0.001 _array_api.py:168(_asarray_with_order)
#      3440    0.002    0.000    0.004    0.000 _array_api.py:63(__getattr__)
#      2220    0.002    0.000    1.007    0.000 _array_api.py:70(asarray)
#      2180    0.004    0.000    0.012    0.000 _array_api.py:90(get_namespace)
#        40    0.001    0.000    0.001    0.000 _available_if.py:25(__get__)
#        20    0.060    0.003    0.090    0.004 _base.py:100(transform)
#        20    0.000    0.000    0.000    0.000 _base.py:102(__init__)
#       120    0.000    0.000    0.000    0.000 _base.py:108(__init__)
#       280    0.002    0.000    0.011    0.000 _base.py:1269(_get_index_dtype)
#      2120    0.002    0.000    0.003    0.000 _base.py:1461(issparse)
#        20    0.002    0.000  402.482   20.124 _base.py:147(fit)
#       140    0.000    0.000    0.000    0.000 _base.py:1490(isspmatrix)
#        80    0.468    0.006    3.719    0.046 _base.py:182(_preprocess_data)
#       320    0.000    0.000    0.001    0.000 _base.py:286(nnz)
#        20    0.000    0.000    0.002    0.000 _base.py:289(_validate_targets)
#        40    0.014    0.000    1.288    0.032 _base.py:294(_rescale_data)
#        20    0.000    0.000    0.000    0.000 _base.py:296(_warn_from_fit_status)
#        40    0.000    0.000    0.000    0.000 _base.py:296(format)
#        20    0.001    0.000  402.206   20.110 _base.py:307(_dense_fit)
#        80    0.008    0.000    0.391    0.005 _base.py:334(_decision_function)
#        80    0.000    0.000    0.392    0.005 _base.py:340(predict)
#        80    0.007    0.000    0.007    0.000 _base.py:356(_set_intercept)
#        20    0.000    0.000    0.530    0.027 _base.py:417(predict)
#        20    0.000    0.000    0.501    0.025 _base.py:437(_dense_predict)
#        80    0.001    0.000    1.264    0.016 _base.py:505(_mul_dispatch)
#        20    0.000    0.000    0.000    0.000 _base.py:508(_compute_kernel)
#        40    0.005    0.000    1.243    0.031 _base.py:593(_mul_multivector)
#        40    0.000    0.000    0.000    0.000 _base.py:605(__init__)
#        20    0.001    0.000    0.030    0.001 _base.py:609(_validate_for_predict)
#        40    0.263    0.007   23.178    0.579 _base.py:618(fit)
#        80    0.000    0.000    1.266    0.016 _base.py:620(__matmul__)
#        20    0.000    0.000    0.001    0.000 _base.py:675(n_support_)
#        20    0.000    0.000    0.081    0.004 _base.py:772(_pre_fit)
#        40    0.005    0.000    0.149    0.004 _base.py:949(tocsr)
#        40   17.186    0.430   17.584    0.440 _basic.py:1113(lstsq)
#        40    0.000    0.000    0.000    0.000 _basic.py:2591(comb)
#        40    0.000    0.000    0.000    0.000 _basic.py:35(_solve_check)
#        20    0.028    0.001    0.030    0.001 _basic.py:52(solve)
#        20    0.000    0.000    0.000    0.000 _classes.py:1189(__init__)
#        20    0.000    0.000    0.000    0.000 _classes.py:121(__init__)
#        20    0.008    0.000   11.434    0.572 _classes.py:1218(fit)
#        20    0.000    0.000    0.000    0.000 _classes.py:1267(__init__)
#        20    0.002    0.000   11.426    0.571 _classes.py:176(fit)
#        20    0.000    0.000    0.026    0.001 _classes.py:389(_validate_X_predict)
#        20    0.000    0.000    0.273    0.014 _classes.py:402(predict)
#        20    0.000    0.000    0.001    0.000 _classes.py:506(_prune_tree)
#       160    0.000    0.000    0.000    0.000 _compressed.py:107(_getnnz)
#        40    0.000    0.000    0.008    0.000 _compressed.py:1080(__get_has_canonical_format)
#        40    0.000    0.000    0.000    0.000 _compressed.py:1102(__set_has_canonical_format)
#        40    0.000    0.000    0.008    0.000 _compressed.py:1110(sum_duplicates)
#        40    0.000    0.000    0.000    0.000 _compressed.py:1142(__set_sorted)
#        40    0.000    0.000    0.001    0.000 _compressed.py:1167(prune)
#        40    0.001    0.000    0.003    0.000 _compressed.py:135(check_format)
#        40    0.001    0.000    0.006    0.000 _compressed.py:25(__init__)
#        40    0.016    0.000    1.089    0.027 _compressed.py:492(_mul_multivector)
#      3320    0.003    0.000    0.005    0.000 _config.py:22(_get_threadlocal_config)
#      3320    0.005    0.000    0.011    0.000 _config.py:30(get_config)
#        40    0.001    0.000    0.012    0.000 _coo.py:132(__init__)
#       160    0.000    0.000    0.000    0.000 _coo.py:247(_getnnz)
#        40    0.001    0.000    0.009    0.000 _coo.py:273(_check)
#        40    0.002    0.000    0.058    0.001 _coo.py:380(tocsr)
#        60    0.000    0.000    0.001    0.000 _coordinate_descent.py:1043(<genexpr>)
#        20    0.000    0.000    0.030    0.001 _coordinate_descent.py:1058(_decision_function)
#        20    0.000    0.000    0.000    0.000 _coordinate_descent.py:1237(__init__)
#        20    0.229    0.011    0.257    0.013 _coordinate_descent.py:350(enet_path)
#        20    0.000    0.000    0.000    0.000 _coordinate_descent.py:39(_set_order)
#        20    0.000    0.000    0.000    0.000 _coordinate_descent.py:829(__init__)
#        20    0.002    0.000    0.505    0.025 _coordinate_descent.py:856(fit)
#        40    0.000    0.000    0.000    0.000 _csc.py:240(isspmatrix_csc)
#       120    0.000    0.000    0.000    0.000 _csr.py:236(_swap)
#        40    0.000    0.000    0.000    0.000 _csr.py:338(isspmatrix_csr)
#       120    0.000    0.000    0.001    0.000 _data.py:20(__init__)
#       160    0.000    0.000    0.000    0.000 _data.py:23(_get_dtype)
#        20    0.371    0.019    0.402    0.020 _decomp_svd.py:13(svd)
#        40    0.000    0.000    0.020    0.001 _dia.py:263(_mul_vector)
#        40    0.061    0.002    0.086    0.002 _dia.py:393(tocoo)
#        40    0.001    0.000    0.007    0.000 _dia.py:89(__init__)
#         2    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         2    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         2    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#        40    0.000    0.000    0.001    0.000 _matrix.py:16(_coo_container)
#        40    0.001    0.000    0.001    0.000 _matrix.py:26(_csr_container)
#       640    0.001    0.000    0.001    0.000 _matrix.py:90(get_shape)
#       580    0.011    0.000    0.189    0.000 _methods.py:101(_mean)
#        20    0.072    0.004    0.176    0.009 _methods.py:135(_var)
#        80    0.000    0.000    0.004    0.000 _methods.py:39(_amax)
#        80    0.000    0.000    0.003    0.000 _methods.py:43(_amin)
#       580    0.001    0.000    0.339    0.001 _methods.py:47(_sum)
#       240    0.000    0.000    0.003    0.000 _methods.py:55(_any)
#       240    0.000    0.000    0.036    0.000 _methods.py:61(_all)
#       600    0.005    0.000    0.005    0.000 _methods.py:67(_count_reduce_items)
#       120    0.000    0.000    0.000    0.000 _misc.py:181(_datacopied)
# 1660/1640    0.005    0.000    0.015    0.000 _param_validation.py:103(make_constraint)
#      2220    0.001    0.000    0.001    0.000 _param_validation.py:226(__init__)
#      1340    0.001    0.000    0.002    0.000 _param_validation.py:258(__init__)
#       460    0.000    0.000    0.000    0.000 _param_validation.py:262(is_satisfied_by)
#       200    0.000    0.000    0.000    0.000 _param_validation.py:272(is_satisfied_by)
#       160    0.004    0.000    0.031    0.000 _param_validation.py:28(validate_parameter_constraints)
#       220    0.000    0.000    0.000    0.000 _param_validation.py:328(is_satisfied_by)
#       100    0.000    0.000    0.001    0.000 _param_validation.py:398(__init__)
#       100    0.000    0.000    0.001    0.000 _param_validation.py:407(_check_params)
#       440    0.003    0.000    0.004    0.000 _param_validation.py:446(__contains__)
#       620    0.001    0.000    0.003    0.000 _param_validation.py:462(_has_valid_type)
#       620    0.001    0.000    0.007    0.000 _param_validation.py:467(is_satisfied_by)
#        80    0.001    0.000    0.002    0.000 _param_validation.py:522(__init__)
#        80    0.000    0.000    0.001    0.000 _param_validation.py:530(is_satisfied_by)
#       320    0.000    0.000    0.000    0.000 _param_validation.py:531(<genexpr>)
#       380    0.002    0.000    0.003    0.000 _param_validation.py:547(__init__)
#       380    0.001    0.000    0.003    0.000 _param_validation.py:555(is_satisfied_by)
#       760    0.000    0.000    0.001    0.000 _param_validation.py:564(<genexpr>)
#        20    0.000    0.000    0.000    0.000 _param_validation.py:580(__init__)
#        20    0.000    0.000    0.000    0.000 _param_validation.py:588(is_satisfied_by)
#        40    0.000    0.000    0.000    0.000 _param_validation.py:589(<genexpr>)
#      1220    0.001    0.000    0.016    0.000 _param_validation.py:74(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _pca.py:383(__init__)
#        20    0.029    0.001    0.783    0.039 _pca.py:438(fit_transform)
#        20    0.001    0.000    0.745    0.037 _pca.py:474(_fit)
#        20    0.102    0.005    0.668    0.033 _pca.py:516(_fit_full)
#        20    0.000    0.000    0.000    0.000 _polynomial.py:132(__init__)
#        40    0.000    0.000    0.000    0.000 _polynomial.py:153(_num_combinations)
#        20    0.000    0.000    0.040    0.002 _polynomial.py:234(fit)
#        40    5.915    0.148    6.137    0.153 _polynomial.py:310(transform)
#       120    0.023    0.000    0.148    0.001 _regression.py:382(mean_squared_error)
#       120    0.004    0.000    0.009    0.000 _regression.py:615(_assemble_r2_explained_variance)
#       240    0.003    0.000    0.174    0.001 _regression.py:66(_check_reg_targets)
#       120    0.030    0.000    0.145    0.001 _regression.py:784(r2_score)
#        20    0.000    0.000    0.000    0.000 _ridge.py:1080(__init__)
#        20    0.016    0.001    0.429    0.021 _ridge.py:1103(fit)
#        20    0.001    0.000    0.199    0.010 _ridge.py:204(_solve_cholesky)
#        20    0.000    0.000    0.000    0.000 _ridge.py:368(_get_valid_accept_sparse)
#        20    0.000    0.000    0.201    0.010 _ridge.py:556(_ridge_regression)
#        20    0.000    0.000    0.000    0.000 _ridge.py:800(__init__)
#        20    0.001    0.000    0.371    0.019 _ridge.py:822(fit)
#    100/80    0.025    0.000    7.076    0.088 _set_output.py:138(wrapped)
#       100    0.001    0.000    0.002    0.000 _set_output.py:63(_get_output_config)
#       100    0.000    0.000    0.002    0.000 _set_output.py:97(_wrap_data_with_container)
#        20    0.000    0.000    0.000    0.000 _split.py:1649(__init__)
#        40    0.000    0.000    0.116    0.003 _split.py:1658(split)
#        20    0.000    0.000    0.000    0.000 _split.py:1809(__init__)
#        40    0.001    0.000    0.115    0.003 _split.py:1820(_iter_indices)
#        40    0.000    0.000    0.000    0.000 _split.py:2164(_validate_shuffle_split)
#        20    0.001    0.000    0.692    0.035 _split.py:2463(train_test_split)
#        60    0.000    0.000    0.572    0.010 _split.py:2586(<genexpr>)
#        40    0.000    0.000    0.000    0.000 _sputils.py:109(getdtype)
#        40    0.000    0.000    0.000    0.000 _sputils.py:135(getdata)
#       280    0.005    0.000    0.008    0.000 _sputils.py:147(get_index_dtype)
#        80    0.000    0.000    0.001    0.000 _sputils.py:211(isscalarlike)
#        80    0.000    0.000    0.000    0.000 _sputils.py:216(isintlike)
#        41    0.000    0.000    0.000    0.000 _sputils.py:22(upcast)
#       120    0.000    0.000    0.001    0.000 _sputils.py:238(isshape)
#        80    0.000    0.000    0.000    0.000 _sputils.py:267(isdense)
#       120    0.001    0.000    0.002    0.000 _sputils.py:294(check_shape)
#       360    0.000    0.000    0.000    0.000 _sputils.py:307(<genexpr>)
#       360    0.000    0.000    0.000    0.000 _sputils.py:312(<genexpr>)
#        80    0.000    0.000    0.000    0.000 _sputils.py:56(upcast_char)
#        80    0.000    0.000    0.000    0.000 _sputils.py:93(to_native)
#      2560    0.009    0.000    0.010    0.000 _ufunc_config.py:132(geterr)
#      2560    0.011    0.000    0.025    0.000 _ufunc_config.py:33(seterr)
#      1280    0.001    0.000    0.001    0.000 _ufunc_config.py:426(__init__)
#      1280    0.003    0.000    0.017    0.000 _ufunc_config.py:430(__enter__)
#      1280    0.004    0.000    0.015    0.000 _ufunc_config.py:435(__exit__)
#       640    0.001    0.000    0.002    0.000 _ufunc_config.py:452(_no_nep50_warning)
#        80    0.000    0.000    0.000    0.000 _util.py:144(_prune_array)
#       140    0.003    0.000    0.410    0.003 _util.py:194(_asarray_validated)
#       120    0.000    0.000    0.000    0.000 _validators.py:128(_check_for_invalid_keys)
#       120    0.000    0.000    0.001    0.000 _validators.py:141(validate_kwargs)
#       120    0.001    0.000    0.002    0.000 _validators.py:168(validate_args_and_kwargs)
#       120    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#       120    0.000    0.000    0.000    0.000 _validators.py:29(_check_arg_length)
#       120    0.000    0.000    0.000    0.000 _validators.py:49(_check_for_default_values)
#       720    0.001    0.000    0.006    0.000 accessor.py:220(__get__)
#       720    0.001    0.000    0.004    0.000 accessor.py:29(__init__)
#       720    0.002    0.000    0.003    0.000 accessor.py:53(_validate)
#        40    0.000    0.000    0.040    0.001 algorithms.py:1211(take)
#       240    0.001    0.000    0.019    0.000 array_ops.py:191(_na_arithmetic_op)
#       240    0.001    0.000    0.022    0.000 array_ops.py:242(arithmetic_op)
#       240    0.001    0.000    0.001    0.000 array_ops.py:509(maybe_prepare_scalar_for_op)
#       240    0.000    0.000    0.000    0.000 array_ops.py:590(_bool_arith_check)
#       120    0.000    0.000    0.049    0.000 arraylike.py:192(__sub__)
#       120    0.000    0.000    0.034    0.000 arraylike.py:240(__pow__)
#       680    0.001    0.000    0.001    0.000 arraysetops.py:125(_unpack_tuple)
#       680    0.000    0.000    0.000    0.000 arraysetops.py:133(_unique_dispatcher)
#       680    0.003    0.000    0.023    0.000 arraysetops.py:138(unique)
#       680    0.012    0.000    0.017    0.000 arraysetops.py:323(_unique1d)
#        80    0.000    0.000    0.000    0.000 base.py:1023(is_classifier)
#        40    0.001    0.000    0.042    0.001 base.py:1139(take)
#        40    0.000    0.000    0.000    0.000 base.py:1169(_maybe_disallow_fill)
#       200    0.003    0.000    0.036    0.000 base.py:122(_get_param_names)
#       200    0.002    0.000    0.002    0.000 base.py:136(<listcomp>)
#       240    0.004    0.000    0.081    0.000 base.py:1370(_arith_method)
#       200    0.001    0.000    0.001    0.000 base.py:151(<listcomp>)
#       200    0.002    0.000    0.039    0.000 base.py:153(get_params)
#        40    0.000    0.000    0.000    0.000 base.py:1657(name)
#         1    0.000    0.000    0.000    0.000 base.py:2774(_na_value)
#      1300    0.001    0.000    0.003    0.000 base.py:346(shape)
#       340    0.001    0.000    0.004    0.000 base.py:348(_check_n_features)
#       120    0.000    0.000    0.000    0.000 base.py:363(ndim)
#       340    0.001    0.000    0.002    0.000 base.py:394(_check_feature_names)
#       340    0.005    0.000    1.564    0.005 base.py:483(_validate_data)
#        40    0.000    0.000    0.000    0.000 base.py:5127(_values)
#       260    0.002    0.000    0.008    0.000 base.py:5404(_can_hold_identifiers_and_holds_name)
#       160    0.001    0.000    0.065    0.000 base.py:592(_validate_params)
#       120    0.000    0.000    0.001    0.000 base.py:61(__len__)
#        40    0.000    0.000    0.001    0.000 base.py:649(_simple_new)
#        80    0.000    0.000    0.001    0.000 base.py:69(shape)
#         1    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#       160    0.000    0.000    0.000    0.000 base.py:71(<genexpr>)
#       240    0.000    0.000    0.001    0.000 base.py:73(_validate_set_axis)
#       480    0.000    0.000    0.000    0.000 base.py:7521(ensure_index)
#       240    0.000    0.000    0.001    0.000 base.py:7616(maybe_extract_name)
#        40    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#        20    0.000    0.000    4.218    0.211 base.py:850(fit_transform)
#      1160    0.001    0.000    0.001    0.000 base.py:909(__len__)
#        21    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         5    0.000    0.000    0.000    0.000 blas.py:259(find_best_blas_type)
#         2    0.000    0.000    0.000    0.000 blas.py:308(<listcomp>)
#         5    0.000    0.000    0.000    0.000 blas.py:326(_get_funcs)
#       120    0.001    0.000    0.001    0.000 blas.py:384(getter)
#        40    0.000    0.000    0.041    0.001 blocks.py:1041(take_nd)
#         1    0.000    0.000    0.000    0.000 blocks.py:226(fill_value)
#       240    0.001    0.000    0.001    0.000 blocks.py:2317(maybe_coerce_values)
#       240    0.000    0.000    0.001    0.000 blocks.py:2346(get_block_type)
#       240    0.001    0.000    0.002    0.000 blocks.py:2388(new_block)
#        40    0.000    0.000    0.000    0.000 blocks.py:265(make_block_same_class)
#        41    0.000    0.000    0.000    0.000 blocks.py:583(dtype)
#        40    0.001    0.000    0.001    0.000 cast.py:550(maybe_promote)
#       360    0.001    0.000    0.004    0.000 common.py:1183(is_bool_dtype)
#       260    0.000    0.000    0.000    0.000 common.py:121(classes)
#       260    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#       360    0.001    0.000    0.001    0.000 common.py:1268(is_extension_array_dtype)
#       260    0.000    0.000    0.003    0.000 common.py:1366(_is_dtype)
#       260    0.001    0.000    0.003    0.000 common.py:137(is_object_dtype)
#       620    0.001    0.000    0.001    0.000 common.py:1390(_get_dtype)
#       260    0.001    0.000    0.001    0.000 common.py:1425(_is_dtype_type)
#       480    0.001    0.000    0.002    0.000 common.py:1562(validate_all_hashable)
#       960    0.001    0.000    0.001    0.000 common.py:1581(<genexpr>)
#       240    0.000    0.000    0.001    0.000 common.py:1587(pandas_dtype)
#       720    0.002    0.000    0.009    0.000 common.py:168(is_sparse)
#       380    0.001    0.000    0.001    0.000 common.py:514(is_string_or_object_np_dtype)
#       260    0.001    0.000    0.004    0.000 common.py:521(is_string_dtype)
#       240    0.000    0.000    0.001    0.000 common.py:556(require_length_match)
#       260    0.001    0.000    0.002    0.000 common.py:557(condition)
#       240    0.001    0.000    0.084    0.000 common.py:62(new_method)
#       240    0.001    0.000    0.002    0.000 common.py:81(get_op_result_name)
#       240    0.001    0.000    0.003    0.000 config.py:127(_get_single_key)
#       240    0.001    0.000    0.005    0.000 config.py:145(_get_option)
#       240    0.000    0.000    0.005    0.000 config.py:271(__call__)
#       240    0.000    0.000    0.000    0.000 config.py:615(_select_options)
#       240    0.001    0.000    0.001    0.000 config.py:633(_get_root)
#       480    0.001    0.000    0.001    0.000 config.py:647(_get_deprecated_option)
#       240    0.000    0.000    0.000    0.000 config.py:674(_translate_key)
#       240    0.000    0.000    0.001    0.000 config.py:686(_warn_if_deprecated)
#       480    0.001    0.000    0.001    0.000 construction.py:420(extract_array)
#       480    0.001    0.000    0.001    0.000 construction.py:485(ensure_wrapped_if_datetimelike)
#       240    0.003    0.000    0.007    0.000 construction.py:519(sanitize_array)
#       240    0.000    0.000    0.001    0.000 construction.py:695(_sanitize_ndim)
#       240    0.000    0.000    0.000    0.000 construction.py:734(_sanitize_str_dtypes)
#       240    0.000    0.000    0.000    0.000 construction.py:754(_maybe_repeat)
#       240    0.001    0.000    0.001    0.000 construction.py:765(_try_cast)
#       400    0.002    0.000    0.002    0.000 contextlib.py:104(__init__)
#       400    0.001    0.000    0.002    0.000 contextlib.py:132(__enter__)
#       400    0.002    0.000    0.003    0.000 contextlib.py:141(__exit__)
#       400    0.001    0.000    0.003    0.000 contextlib.py:299(helper)
#       140    0.000    0.000    0.000    0.000 core.py:6485(isMaskedArray)
#       240    0.001    0.000    0.002    0.000 dispatch.py:17(should_extension_dispatch)
#      1540    0.001    0.000    0.001    0.000 enum.py:1093(__new__)
#      1540    0.002    0.000    0.002    0.000 enum.py:686(__call__)
#       240    0.000    0.000    0.017    0.000 expressions.py:226(evaluate)
#       240    0.000    0.000    0.015    0.000 expressions.py:67(_evaluate_standard)
#       240    0.000    0.000    0.000    0.000 expressions.py:76(_can_use_numexpr)
#       240    0.001    0.000    0.016    0.000 expressions.py:95(_evaluate_numexpr)
#       200    0.248    0.001    1.515    0.008 extmath.py:156(safe_sparse_dot)
#        20    0.077    0.004    0.093    0.005 extmath.py:766(svd_flip)
#       280    0.000    0.000    0.000    0.000 flags.py:53(__init__)
#       280    0.000    0.000    0.000    0.000 flags.py:57(allows_duplicate_labels)
#       280    0.000    0.000    0.000    0.000 flags.py:89(allows_duplicate_labels)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:1136(_argmax_dispatcher)
#        20    0.000    0.000    0.016    0.001 fromnumeric.py:1140(argmax)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#        60    0.000    0.000    0.000    0.000 fromnumeric.py:195(_reshape_dispatcher)
#        60    0.000    0.000    0.001    0.000 fromnumeric.py:200(reshape)
#      1180    0.000    0.000    0.000    0.000 fromnumeric.py:2172(_sum_dispatcher)
#      1180    0.005    0.000    1.757    0.001 fromnumeric.py:2177(sum)
#        80    0.000    0.000    0.000    0.000 fromnumeric.py:2317(_any_dispatcher)
#        80    0.000    0.000    0.002    0.000 fromnumeric.py:2322(any)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:2687(_max_dispatcher)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:2692(max)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:2831(_min_dispatcher)
#        40    0.000    0.000    0.003    0.000 fromnumeric.py:2836(min)
#        80    0.000    0.000    0.000    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#        80    0.000    0.000    0.000    0.000 fromnumeric.py:3176(ndim)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:3380(_mean_dispatcher)
#        20    0.000    0.000    0.070    0.003 fromnumeric.py:3385(mean)
#        80    0.000    0.000    0.016    0.000 fromnumeric.py:53(_wrapfunc)
#      1320    0.007    0.000    1.756    0.001 fromnumeric.py:71(_wrapreduction)
#      1320    0.002    0.000    0.002    0.000 fromnumeric.py:72(<dictcomp>)
#       120    0.000    0.000    0.003    0.000 function.py:411(validate_func)
#       160    0.001    0.000    0.003    0.000 function.py:64(__call__)
#        40    0.000    0.000    0.000    0.000 function_base.py:348(iterable)
#       640    0.000    0.000    0.000    0.000 function_base.py:393(_average_dispatcher)
#       640    1.297    0.002    1.718    0.003 function_base.py:398(average)
#       140    0.371    0.003    0.407    0.003 function_base.py:564(asarray_chkfinite)
#       120    0.001    0.000    0.026    0.000 generic.py:12031(_min_count_stat_function)
#       120    0.001    0.000    0.027    0.000 generic.py:12070(sum)
#       280    0.002    0.000    0.002    0.000 generic.py:274(__init__)
#        40    0.000    0.000    0.000    0.000 generic.py:335(_from_mgr)
#       280    0.000    0.000    0.000    0.000 generic.py:358(attrs)
#      2160    0.002    0.000    0.002    0.000 generic.py:37(_check)
#       560    0.000    0.000    0.000    0.000 generic.py:393(flags)
#        40    0.001    0.000    0.116    0.003 generic.py:3962(take)
#      2160    0.002    0.000    0.004    0.000 generic.py:42(_instancecheck)
#       240    0.000    0.000    0.001    0.000 generic.py:487(_validate_dtype)
#       160    0.000    0.000    0.000    0.000 generic.py:548(_get_axis_number)
#        40    0.000    0.000    0.000    0.000 generic.py:568(_get_block_manager_axis)
#       280    0.003    0.000    0.004    0.000 generic.py:6147(__finalize__)
#      1580    0.006    0.000    0.017    0.000 generic.py:6189(__getattr__)
#       520    0.002    0.000    0.007    0.000 generic.py:6206(__setattr__)
#       260    0.000    0.000    0.001    0.000 generic.py:638(_info_axis)
#       240    0.001    0.000    0.002    0.000 generic.py:760(_set_axis)
#        40    0.000    0.000    0.000    0.000 getlimits.py:484(__new__)
#       600    0.003    0.000    0.003    0.000 getlimits.py:685(__init__)
#       280    0.000    0.000    0.000    0.000 getlimits.py:696(min)
#       320    0.000    0.000    0.000    0.000 getlimits.py:709(max)
#       400    0.001    0.000    0.001    0.000 indexing.py:150(iloc)
#        40    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#       720    0.001    0.000    0.001    0.000 inference.py:334(is_hashable)
#       200    0.001    0.000    0.001    0.000 inspect.py:167(get_annotations)
#       200    0.007    0.000    0.023    0.000 inspect.py:2333(_signature_from_function)
#       200    0.004    0.000    0.028    0.000 inspect.py:2428(_signature_from_callable)
#      1540    0.006    0.000    0.009    0.000 inspect.py:2686(__init__)
#      4420    0.001    0.000    0.001    0.000 inspect.py:2739(name)
#      2680    0.001    0.000    0.001    0.000 inspect.py:2751(kind)
#       240    0.000    0.000    0.001    0.000 inspect.py:292(isclass)
#       200    0.002    0.000    0.004    0.000 inspect.py:2972(__init__)
#      1740    0.001    0.000    0.001    0.000 inspect.py:3019(<genexpr>)
#       200    0.001    0.000    0.029    0.000 inspect.py:3024(from_callable)
#       200    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#       200    0.000    0.000    0.029    0.000 inspect.py:3278(signature)
#       400    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#       200    0.001    0.000    0.001    0.000 inspect.py:735(unwrap)
#       200    0.000    0.000    0.000    0.000 inspect.py:755(_is_wrapper)
#        62    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#        62    0.000    0.000    0.004    0.000 iostream.py:258(schedule)
#       280    0.000    0.000    0.001    0.000 iostream.py:519(_is_master_process)
#       280    0.000    0.000    0.004    0.000 iostream.py:546(_schedule_flush)
#       280    0.002    0.000    0.007    0.000 iostream.py:624(write)
#       120    0.000    0.000    0.001    0.000 lapack.py:1010(<genexpr>)
#       100    0.001    0.000    0.001    0.000 lapack.py:1014(_check_work_float)
#         5    0.000    0.000    0.000    0.000 lapack.py:881(get_lapack_funcs)
#        60    0.015    0.000    0.016    0.000 lapack.py:979(_compute_lwork)
#        40    0.000    0.000    0.000    0.000 logger.py:67(__init__)
#        80    0.000    0.000    0.000    0.000 managers.py:1790(ndim)
#       280    0.000    0.000    0.000    0.000 managers.py:1799(__init__)
#        40    0.000    0.000    0.000    0.000 managers.py:1812(from_blocks)
#       240    0.002    0.000    0.005    0.000 managers.py:1825(from_array)
#       281    0.000    0.000    0.000    0.000 managers.py:1902(_block)
#      3240    0.002    0.000    0.002    0.000 managers.py:1949(dtype)
#      2020    0.003    0.000    0.003    0.000 managers.py:1960(internal_values)
#       240    0.000    0.000    0.001    0.000 managers.py:225(set_axis)
#        40    0.000    0.000    0.000    0.000 managers.py:2268(_preprocess_slice_or_indexer)
#       120    0.000    0.000    0.000    0.000 managers.py:235(items)
#        40    0.001    0.000    0.043    0.001 managers.py:606(reindex_indexer)
#        40    0.001    0.000    0.043    0.001 managers.py:691(_slice_take_blocks_ax0)
#        40    0.001    0.000    0.104    0.003 managers.py:852(take)
#        40    0.000    0.000    0.000    0.000 memory.py:100(_store_backend_factory)
#        40    0.000    0.000    0.000    0.000 memory.py:345(__init__)
#        40    0.000    0.000    5.003    0.125 memory.py:348(__call__)
#        40    0.001    0.000    0.001    0.000 memory.py:910(__init__)
#        40    0.000    0.000    0.000    0.000 memory.py:937(cache)
#        40    0.000    0.000    0.006    0.000 metaestimators.py:30(_get_params)
#        40    0.000    0.000    0.007    0.000 metaestimators.py:82(_validate_names)
#        40    0.000    0.000    0.000    0.000 metaestimators.py:92(<listcomp>)
#       120    0.000    0.000    0.007    0.000 missing.py:101(isna)
#       240    0.001    0.000    0.001    0.000 missing.py:131(dispatch_fill_zeros)
#       120    0.001    0.000    0.006    0.000 missing.py:184(_isna)
#       120    0.005    0.000    0.005    0.000 missing.py:261(_isna_array)
#         1    0.000    0.000    0.000    0.000 missing.py:642(na_value_for_dtype)
#       260    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#       100    0.000    0.000    0.000    0.000 multiarray.py:1393(may_share_memory)
#       466    0.000    0.000    0.000    0.000 multiarray.py:503(can_cast)
#        82    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#       100    0.000    0.000    0.000    0.000 multiarray.py:741(dot)
#        80    0.000    0.000    0.000    0.000 multiarray.py:85(empty_like)
#       120    0.000    0.000    0.000    0.000 nanops.py:1491(_maybe_null_out)
#       120    0.000    0.000    0.000    0.000 nanops.py:1539(check_below_min_count)
#       120    0.000    0.000    0.000    0.000 nanops.py:187(_get_fill_value)
#       120    0.000    0.000    0.007    0.000 nanops.py:209(_maybe_get_mask)
#       120    0.001    0.000    0.009    0.000 nanops.py:253(_get_values)
#       120    0.000    0.000    0.000    0.000 nanops.py:324(_get_dtype_max)
#       120    0.001    0.000    0.018    0.000 nanops.py:389(new_func)
#       120    0.000    0.000    0.017    0.000 nanops.py:455(newfunc)
#       120    0.001    0.000    0.017    0.000 nanops.py:604(nansum)
#       360    0.000    0.000    0.000    0.000 nanops.py:72(check)
#       120    0.001    0.000    0.020    0.000 nanops.py:76(_f)
#       480    0.000    0.000    0.001    0.000 nanops.py:79(<genexpr>)
#       260    0.020    0.000    0.022    0.000 numeric.py:136(ones)
#       160    0.001    0.000    0.002    0.000 numeric.py:1855(isscalar)
#        20    0.000    0.000    0.000    0.000 numeric.py:2374(_array_equal_dispatcher)
#        20    0.000    0.000    0.001    0.000 numeric.py:2378(array_equal)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:283(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:357(issubdtype)
#        40    0.000    0.000    0.000    0.000 pipeline.py:145(__init__)
#        40    0.000    0.000    0.006    0.000 pipeline.py:173(get_params)
#        40    0.000    0.000    0.007    0.000 pipeline.py:214(_validate_steps)
#       160    0.001    0.000    0.001    0.000 pipeline.py:249(_iter)
#       120    0.000    0.000    0.000    0.000 pipeline.py:307(_final_estimator)
#        80    0.000    0.000    0.000    0.000 pipeline.py:312(_log_message)
#        40    0.000    0.000    0.000    0.000 pipeline.py:319(_check_fit_params)
#        40    0.000    0.000    0.000    0.000 pipeline.py:320(<dictcomp>)
#        40    0.001    0.000    5.012    0.125 pipeline.py:336(_fit)
#        40    0.333    0.008   28.525    0.713 pipeline.py:374(fit)
#        40    0.000    0.000    0.000    0.000 pipeline.py:44(check)
#        40    0.001    0.000    2.416    0.060 pipeline.py:449(predict)
#        40    0.001    0.000    0.001    0.000 pipeline.py:803(_name_estimators)
#        40    0.000    0.000    0.000    0.000 pipeline.py:806(<listcomp>)
#        40    0.000    0.000    0.001    0.000 pipeline.py:827(make_pipeline)
#        40    0.000    0.000    5.003    0.125 pipeline.py:883(_fit_transform_one)
#       240    0.000    0.000    0.000    0.000 series.py:1381(_clear_item_cache)
#       240    0.005    0.000    0.036    0.000 series.py:371(__init__)
#       280    0.000    0.000    0.000    0.000 series.py:577(_constructor)
#        40    0.000    0.000    0.001    0.000 series.py:581(_constructor_from_mgr)
#       240    0.001    0.000    0.082    0.000 series.py:5817(_arith_method)
#       240    0.000    0.000    0.000    0.000 series.py:5821(_align_for_op)
#       240    0.002    0.000    0.044    0.000 series.py:5885(_construct_result)
#       120    0.001    0.000    0.022    0.000 series.py:6094(_reduce)
#       120    0.000    0.000    0.027    0.000 series.py:6195(sum)
#      3240    0.002    0.000    0.005    0.000 series.py:626(dtype)
#       720    0.000    0.000    0.001    0.000 series.py:639(dtypes)
#       720    0.001    0.000    0.002    0.000 series.py:653(name)
#       480    0.001    0.000    0.003    0.000 series.py:703(name)
#      2020    0.002    0.000    0.005    0.000 series.py:750(_values)
#       120    0.000    0.000    0.001    0.000 series.py:821(__len__)
#       360    0.001    0.000    0.003    0.000 series.py:905(__array__)
#        40    0.000    0.000    0.000    0.000 shape_base.py:1181(_tile_dispatcher)
#        40    0.001    0.000    0.002    0.000 shape_base.py:1185(tile)
#        80    0.000    0.000    0.000    0.000 shape_base.py:1257(<genexpr>)
#        80    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#        80    0.000    0.000    0.000    0.000 shape_base.py:23(atleast_1d)
#        60    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#        60    0.000    0.000    0.001    0.000 shape_base.py:81(atleast_2d)
#        62    0.003    0.000    0.003    0.000 socket.py:621(send)
#        40    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#        40    0.001    0.000    0.002    0.000 stride_tricks.py:340(_broadcast_to)
#       120    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#        40    0.000    0.000    0.000    0.000 stride_tricks.py:363(_broadcast_to_dispatcher)
#        40    0.000    0.000    0.002    0.000 stride_tricks.py:367(broadcast_to)
#        40    0.001    0.000    0.040    0.001 take.py:121(_take_nd_ndarray)
#         1    0.000    0.000    0.000    0.000 take.py:288(_get_take_nd_function_cached)
#        40    0.000    0.000    0.000    0.000 take.py:326(_get_take_nd_function)
#        40    0.000    0.000    0.001    0.000 take.py:565(_take_preprocess_indexer_and_fill_value)
#        40    0.000    0.000    0.041    0.001 take.py:59(take_nd)
#        62    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#        62    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#        62    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#       240    0.000    0.000    0.000    0.000 typing.py:2268(cast)
#        40    0.016    0.000    0.017    0.000 utils.py:239(maybe_convert_indices)
#       100    0.000    0.000    0.056    0.001 validation.py:1129(_check_y)
#        40    0.000    0.000    0.007    0.000 validation.py:1152(column_or_1d)
#        80    0.000    0.000    0.000    0.000 validation.py:1207(check_random_state)
#       240    0.002    0.000    0.008    0.000 validation.py:1322(check_is_fitted)
#       240    0.003    0.000    0.005    0.000 validation.py:1385(<listcomp>)
#        40    0.000    0.000    0.004    0.000 validation.py:1393(check_non_negative)
#        20    0.000    0.000    0.000    0.000 validation.py:1421(check_scalar)
#        40    0.000    0.000    0.016    0.000 validation.py:1716(_check_sample_weight)
#       340    0.000    0.000    0.001    0.000 validation.py:1870(_get_feature_names)
#        40    0.000    0.000    0.000    0.000 validation.py:257(_is_arraylike)
#        40    0.000    0.000    0.001    0.000 validation.py:262(_is_arraylike_not_scalar)
#       340    0.002    0.000    0.003    0.000 validation.py:267(_num_features)
#      2500    0.019    0.000    0.054    0.000 validation.py:320(_num_samples)
#        40    0.000    0.000    0.001    0.000 validation.py:349(check_memory)
#       640    0.004    0.000    0.061    0.000 validation.py:383(check_consistent_length)
#       640    0.002    0.000    0.034    0.000 validation.py:394(<listcomp>)
#       100    0.000    0.000    0.000    0.000 validation.py:403(_make_indexable)
#        40    0.000    0.000    0.003    0.000 validation.py:423(indexable)
#        40    0.000    0.000    0.000    0.000 validation.py:442(<listcomp>)
#      1080    0.002    0.000    0.003    0.000 validation.py:571(_ensure_no_complex_data)
#      1080    0.001    0.000    0.001    0.000 validation.py:581(_check_estimator_name)
#       360    0.005    0.000    0.022    0.000 validation.py:590(_pandas_dtype_needs_early_conversion)
#      1060    0.031    0.000    3.241    0.003 validation.py:629(check_array)
#      1040    0.031    0.000    1.795    0.002 validation.py:96(_assert_all_finite)
#       100    0.001    0.000    0.789    0.008 validation.py:981(check_X_y)
#      1060    0.002    0.000    0.010    0.000 warnings.py:165(simplefilter)
#      1060    0.004    0.000    0.007    0.000 warnings.py:181(_add_filter)
#      1060    0.002    0.000    0.002    0.000 warnings.py:440(__init__)
#      1060    0.004    0.000    0.004    0.000 warnings.py:466(__enter__)
#      1060    0.002    0.000    0.003    0.000 warnings.py:487(__exit__)
#        80    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFF2B1FC4D0}
#      5980    0.007    0.000    0.012    0.000 {built-in method _abc._abc_instancecheck}
# 3176/3169    0.004    0.000    0.004    0.000 {built-in method _abc._abc_subclasscheck}
#       420    0.000    0.000    0.000    0.000 {built-in method _operator.ge}
#        20    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#       240    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        80    0.000    0.000    0.000    0.000 {built-in method _operator.le}
#       380    0.000    0.000    0.000    0.000 {built-in method _operator.lt}
#       120    0.006    0.000    0.006    0.000 {built-in method _operator.pow}
#       120    0.009    0.000    0.009    0.000 {built-in method _operator.sub}
#      3180    0.001    0.000    0.001    0.000 {built-in method _warnings._filters_mutated}
#       720    0.007    0.000    0.007    0.000 {built-in method _warnings.warn}
#       540    0.001    0.000    0.003    0.000 {built-in method builtins.all}
#       760    0.001    0.000    0.003    0.000 {built-in method builtins.any}
#       520    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000  448.262  448.262 {built-in method builtins.exec}
#     12916    0.006    0.000    0.007    0.000 {built-in method builtins.getattr}
# 23780/23520    0.016    0.000    0.038    0.000 {built-in method builtins.hasattr}
#       763    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       200    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     46452    0.018    0.000    0.038    0.000 {built-in method builtins.isinstance}
#      2508    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 11064/9664    0.004    0.000    0.005    0.000 {built-in method builtins.len}
#       282    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       820    0.001    0.000    0.119    0.000 {built-in method builtins.next}
#       140    0.001    0.000    0.008    0.000 {built-in method builtins.print}
#        80    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#       200    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#       240    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#        20    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#        20    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#       280    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        40    0.006    0.000    0.006    0.000 {built-in method numpy.arange}
#       760    1.006    0.001    1.006    0.001 {built-in method numpy.array}
#      3440    0.003    0.000    0.003    0.000 {built-in method numpy.asanyarray}
# 4960/4600    0.326    0.000    0.329    0.000 {built-in method numpy.asarray}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.asfortranarray}
#       620    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      1120    0.005    0.000    0.005    0.000 {built-in method numpy.empty}
#      5120    0.002    0.000    0.002    0.000 {built-in method numpy.geterrobj}
#      2560    0.004    0.000    0.004    0.000 {built-in method numpy.seterrobj}
#       120    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        40    0.039    0.001    0.039    0.001 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#        40    0.007    0.000    0.007    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#        40    0.997    0.025    0.997    0.025 {built-in method scipy.sparse._sparsetools.csr_matvecs}
#        40    0.019    0.000    0.019    0.000 {built-in method scipy.sparse._sparsetools.dia_matvec}
#       200    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#       320    0.000    0.000    0.000    0.000 {built-in method time.time}
#      1540    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#       280    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        40    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#        62    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#        20    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#       220    0.001    0.000    0.037    0.000 {method 'all' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.generic' objects}
#       200    0.000    0.000    0.003    0.000 {method 'any' of 'numpy.ndarray' objects}
#        62    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#      3008    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#        20    0.016    0.001    0.016    0.001 {method 'argmax' of 'numpy.ndarray' objects}
#       300    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        20   11.350    0.567   11.350    0.567 {method 'build' of 'sklearn.tree._tree.DepthFirstTreeBuilder' objects}
#      3440    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      3860    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#       680    0.002    0.000    0.002    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      3646    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#        62    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#      1060    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#        40    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#      1540    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#      1580    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#        80    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        80    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        80    0.000    0.000    0.004    0.000 {method 'max' of 'numpy.ndarray' objects}
#       560    0.001    0.000    0.120    0.000 {method 'mean' of 'numpy.ndarray' objects}
#        80    0.000    0.000    0.003    0.000 {method 'min' of 'numpy.ndarray' objects}
#        20    0.114    0.006    0.114    0.006 {method 'permutation' of 'numpy.random.mtrand.RandomState' objects}
#       140    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        20    0.246    0.012    0.246    0.012 {method 'predict' of 'sklearn.tree._tree.Tree' objects}
#        20    0.001    0.000    0.001    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#       280    0.075    0.000    0.075    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      3000    2.370    0.001    2.370    0.001 {method 'reduce' of 'numpy.ufunc' objects}
#      1060    0.002    0.000    0.002    0.000 {method 'remove' of 'list' objects}
#       320    0.000    0.000    0.000    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#       600    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       360    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       320    0.001    0.000    0.001    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#       680    0.002    0.000    0.002    0.000 {method 'sort' of 'numpy.ndarray' objects}
#       240    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#      1300    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       560    0.002    0.000    0.313    0.001 {method 'sum' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        40    0.040    0.001    0.040    0.001 {method 'take' of 'numpy.ndarray' objects}
#       120    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       240    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       200    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        20    0.013    0.001    0.190    0.009 {method 'var' of 'numpy.ndarray' objects}
#       280    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       160    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        40    0.038    0.001    0.038    0.001 {pandas._libs.algos.take_1d_float64_float64}
#       240    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       520    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        40    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_np_dtype}
#       160    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       240    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        40    0.000    0.000    0.000    0.000 {scipy.special._comb._comb_int}
#        20  402.197   20.110  402.205   20.110 {sklearn.svm._libsvm.fit}
#        20    0.500    0.025    0.500    0.025 {sklearn.svm._libsvm.predict}
#        20    0.000    0.000    0.000    0.000 {sklearn.svm._libsvm.set_verbosity_wrap}
#
#
#                                                MSE          RMSE  \
# Regression Tree                       7.222203e+01  8.176662e+00
# Ridge Regression                      1.112000e-06  9.151716e-04
# Lasso Regression                      1.848028e+00  1.358594e+00
# Principal Component Regression (PCR)  6.427597e-26  2.316610e-13
# Regression Splines                    1.329876e-16  3.768268e-09
# Support Vector Regression (SVR)       8.240817e-03  9.074079e-02
#
#                                                RSE           RSS       R^2
# Regression Tree                       8.177190e+00  4.467366e+06  0.992408
# Ridge Regression                      9.152308e-04  6.878387e-02  1.000000
# Lasso Regression                      1.358682e+00  1.143116e+05  0.999802
# Principal Component Regression (PCR)  2.316759e-13  3.975854e-21  1.000000
# Regression Splines                    3.768511e-09  8.226080e-12  1.000000
# Support Vector Regression (SVR)       9.074665e-02  5.097440e+02  0.999999

# %%
results_df
# Out:
#                                                MSE          RMSE  \
# Regression Tree                       7.222203e+01  8.176662e+00
# Ridge Regression                      1.112000e-06  9.151716e-04
# Lasso Regression                      1.848028e+00  1.358594e+00
# Principal Component Regression (PCR)  6.427597e-26  2.316610e-13
# Regression Splines                    1.329876e-16  3.768268e-09
# Support Vector Regression (SVR)       8.240817e-03  9.074079e-02
#
#                                                RSE           RSS       R^2
# Regression Tree                       8.177190e+00  4.467366e+06  0.992408
# Ridge Regression                      9.152308e-04  6.878387e-02  1.000000
# Lasso Regression                      1.358682e+00  1.143116e+05  0.999802
# Principal Component Regression (PCR)  2.316759e-13  3.975854e-21  1.000000
# Regression Splines                    3.768511e-09  8.226080e-12  1.000000
# Support Vector Regression (SVR)       9.074665e-02  5.097440e+02  0.999999

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.tree import DecisionTreeRegressor

# Define parameter grids for hyperparameter tuning
param_grids = {
    'Ridge Regression': {'ridge__alpha': [0.01, 0.1, 1, 10, 100]},
    'Lasso Regression': {'lasso__alpha': [0.01, 0.1, 1, 10, 100]},
    'Principal Component Regression (PCR)': {'pca__n_components': [1, 2, 3, 4, X.shape[1]]},
    'Regression Splines': {'polynomialfeatures__degree': [2, 3, 4]},
    'Regression Tree': {
      'decisiontreeregressor__max_depth': [3, 4, 5],
      'decisiontreeregressor__min_samples_split': [10, 15, 20],
      'decisiontreeregressor__min_samples_leaf': [4, 8, 10]
},
    'Support Vector Regression (SVR)': {'svr__C': [0.1, 1, 10], 'svr__epsilon': [0.1, 0.5, 1], 'svr__kernel': ['linear']}

}



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
# Function to calculate metrics
def calculate_metrics(y_true, y_pred, n_features):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    rss = np.sum((y_true - y_pred) ** 2)
    rse = np.sqrt(rss / (len(y_true) - n_features - 1))
    r2 = r2_score(y_true, y_pred)
    return {'MSE': mse, 'RMSE': rmse, 'RSE': rse, 'RSS': rss, 'R²': r2}

# Function to plot learning curves

def plot_learning_curve(model, X, y, model_name, cv=5):
    train_sizes, train_scores, test_scores = learning_curve(
        model, X, y, cv=cv, scoring='neg_mean_squared_error', n_jobs=-1
    )
    train_rmse = np.sqrt(-train_scores.mean(axis=1))
    test_rmse = np.sqrt(-test_scores.mean(axis=1))

    plt.figure(figsize=(8, 6))
    plt.plot(train_sizes, train_rmse, label="Training RMSE", marker='o')
    plt.plot(train_sizes, test_rmse, label="Validation RMSE", marker='o')
    plt.title(f"Learning Curve for {model_name}")
    plt.xlabel("Training Set Size")
    plt.ylabel("Root Mean Squared Error (RMSE)")
    plt.legend()
    plt.grid()
    plt.show()

# Dictionary to store results
results = {}
best_parameters = {}

# Iterate over each model and perform GridSearchCV
for model_name, grid_params in param_grids.items():
    print(f"Running GridSearchCV for {model_name}...")
    
    # Define the model pipeline
    if model_name == 'Principal Component Regression (PCR)':
        model = make_pipeline(StandardScaler(), PCA(), LinearRegression())
    elif model_name == 'Regression Splines':
        model = make_pipeline(PolynomialFeatures(), LinearRegression())
    elif model_name == 'Ridge Regression':
        model = make_pipeline(StandardScaler(), Ridge(max_iter=5000))
    elif model_name == 'Lasso Regression':
        model = make_pipeline(StandardScaler(), Lasso(max_iter=5000))
    elif model_name == 'Regression Tree':
        model = make_pipeline(StandardScaler(), DecisionTreeRegressor())
    elif model_name == 'Support Vector Regression (SVR)':
        model = make_pipeline(StandardScaler(), SVR())

    # Perform GridSearchCV
    grid_search = GridSearchCV(model, grid_params, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train_scaled, y_train)
    
    # Store the best parameters
    best_parameters[model_name] = grid_search.best_params_
    
    # Predict on the test set using the best estimator
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test_scaled)
    
    # Calculate performance metrics
    metrics = calculate_metrics(y_test, y_pred, X_test_scaled.shape[1])
    results[model_name] = metrics

    print(f"{model_name} - Best Parameters: {grid_search.best_params_}")
    print(f"{model_name} - Metrics: {metrics}\n")

    # Plot learning curve for the best model
    plot_learning_curve(best_model, X_train_scaled, y_train, model_name)

# Convert results to DataFrame for better visualization
results_df = pd.DataFrame(results).T
print("\nModel Performance Metrics:")
print(results_df)

# Display best parameters for each model
print("\nBest Parameters for Each Model:")
for model_name, params in best_parameters.items():
    print(f"{model_name}: {params}")
# Out:
# Running GridSearchCV for Ridge Regression...
# Ridge Regression - Best Parameters: {'ridge__alpha': 0.01}
# Ridge Regression - Metrics: {'MSE': 5.864703392015989e-11, 'RMSE': 7.658135146376034e-06, 'RSE': 7.658630417849237e-06, 'RSS': 3.62767093016541e-06, 'R²': 0.9999999999999939}
# Running GridSearchCV for Lasso Regression...
# Lasso Regression - Best Parameters: {'lasso__alpha': 0.01}
# Lasso Regression - Metrics: {'MSE': 0.0001701902024942663, 'RMSE': 0.013045696704057867, 'RSE': 0.013046540403118026, 'RSS': 10.527285165485337, 'R²': 0.9999999822325644}
# Running GridSearchCV for Principal Component Regression (PCR)...
# Principal Component Regression (PCR) - Best Parameters: {'pca__n_components': 7}
# Principal Component Regression (PCR) - Metrics: {'MSE': 2.18904563745547e-26, 'RMSE': 1.4795423743358855e-13, 'RSE': 1.4796380601807286e-13, 'RSS': 1.3540560695044554e-21, 'R²': 1.0}
# Running GridSearchCV for Regression Splines...
# Regression Splines - Best Parameters: {'polynomialfeatures__degree': 2}
# Regression Splines - Metrics: {'MSE': 1.8984739233605396e-24, 'RMSE': 1.3778511978296276e-12, 'RSE': 1.3779403070421917e-12, 'RSS': 1.1743200300338955e-19, 'R²': 1.0}
# Running GridSearchCV for Regression Tree...
# Regression Tree - Best Parameters: {'decisiontreeregressor__max_depth': 5, 'decisiontreeregressor__min_samples_leaf': 4, 'decisiontreeregressor__min_samples_split': 20}
# Regression Tree - Metrics: {'MSE': 424.96335824774513, 'RMSE': 20.614639415904055, 'RSE': 20.615972618131217, 'RSS': 26286533.487772524, 'R²': 0.9556348779355757}
# Running GridSearchCV for Support Vector Regression (SVR)...
# Support Vector Regression (SVR) - Best Parameters: {'svr__C': 0.1, 'svr__epsilon': 0.1, 'svr__kernel': 'linear'}
# Support Vector Regression (SVR) - Metrics: {'MSE': 0.006987149188556277, 'RMSE': 0.08358916908640902, 'RSE': 0.08359457501489237, 'RSS': 432.1971002073371, 'R²': 0.9999992705589302}
# Model Performance Metrics:
#                                                MSE          RMSE  \
# Ridge Regression                      5.864703e-11  7.658135e-06
# Lasso Regression                      1.701902e-04  1.304570e-02
# Principal Component Regression (PCR)  2.189046e-26  1.479542e-13
# Regression Splines                    1.898474e-24  1.377851e-12
# Regression Tree                       4.249634e+02  2.061464e+01
# Support Vector Regression (SVR)       6.987149e-03  8.358917e-02
#
#                                                RSE           RSS        R²
# Ridge Regression                      7.658630e-06  3.627671e-06  1.000000
# Lasso Regression                      1.304654e-02  1.052729e+01  1.000000
# Principal Component Regression (PCR)  1.479638e-13  1.354056e-21  1.000000
# Regression Splines                    1.377940e-12  1.174320e-19  1.000000
# Regression Tree                       2.061597e+01  2.628653e+07  0.955635
# Support Vector Regression (SVR)       8.359458e-02  4.321971e+02  0.999999
#
# Best Parameters for Each Model:
# Ridge Regression: {'ridge__alpha': 0.01}
# Lasso Regression: {'lasso__alpha': 0.01}
# Principal Component Regression (PCR): {'pca__n_components': 7}
# Regression Splines: {'polynomialfeatures__degree': 2}
# Regression Tree: {'decisiontreeregressor__max_depth': 5, 'decisiontreeregressor__min_samples_leaf': 4, 'decisiontreeregressor__min_samples_split': 20}
# Support Vector Regression (SVR): {'svr__C': 0.1, 'svr__epsilon': 0.1, 'svr__kernel': 'linear'}

# %%
results_df
# Out:
#                                                MSE          RMSE  \
# Ridge Regression                      5.864703e-11  7.658135e-06
# Lasso Regression                      1.701902e-04  1.304570e-02
# Principal Component Regression (PCR)  2.189046e-26  1.479542e-13
# Regression Splines                    1.898474e-24  1.377851e-12
# Regression Tree                       4.249634e+02  2.061464e+01
# Support Vector Regression (SVR)       6.987149e-03  8.358917e-02
#
#                                                RSE           RSS        R²
# Ridge Regression                      7.658630e-06  3.627671e-06  1.000000
# Lasso Regression                      1.304654e-02  1.052729e+01  1.000000
# Principal Component Regression (PCR)  1.479638e-13  1.354056e-21  1.000000
# Regression Splines                    1.377940e-12  1.174320e-19  1.000000
# Regression Tree                       2.061597e+01  2.628653e+07  0.955635
# Support Vector Regression (SVR)       8.359458e-02  4.321971e+02  0.999999
